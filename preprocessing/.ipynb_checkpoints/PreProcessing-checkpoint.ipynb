# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../../dataset/household_power_consumption.txt', sep=';', na_values='?', dtype = {'Gobal_active_power': float, 
        'Global_reactive_power': float, 'Voltage': float, 'Global_intensity': float, 'Sub_metering_1': float, 
        'Sub_metering_2': float,'Sub_metering_3': float})

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_timedelta(df['Time'])
df['DateTime'] =  df['Date'] + df['Time']

#Nearest neighbour interpolation used because electricity reading is less likely to change dramatically in a timeseries
#this frequency
df = df.interpolate(method='nearest', axis=0).ffill().bfill()

# writing to csv
df['Time'] = pd.to_timedelta(df['Time'])
df.to_csv('../../dataset/cleaned.csv')
# Out:
#         Date          Time  Global_active_power  Global_reactive_power  \
# 0 2006-12-16  6.264000e+13                4.216                  0.418
# 1 2006-12-16  6.270000e+13                5.360                  0.436
# 2 2006-12-16  6.276000e+13                5.374                  0.498
# 3 2006-12-16  6.282000e+13                5.388                  0.502
# 4 2006-12-16  6.288000e+13                3.666                  0.528
#
#    Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0   234.84              18.4             0.0             1.0            17.0
# 1   233.63              23.0             0.0             1.0            16.0
# 2   233.29              23.0             0.0             2.0            17.0
# 3   233.74              23.0             0.0             1.0            17.0
# 4   235.68              15.8             0.0             1.0            17.0
#
#              DateTime
# 0 2006-12-16 17:24:00
# 1 2006-12-16 17:25:00
# 2 2006-12-16 17:26:00
# 3 2006-12-16 17:27:00
# 4 2006-12-16 17:28:00
